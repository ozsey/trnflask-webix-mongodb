# %% [markdown]
# # Modul 1

# %%
#Jawaban nomor 2 soal latihan
print("Latihan Algoritma dan Struktur data")
print("nama:Anugrah Adhiantoro")
print("nim:B220231008")
print("angkatan: 2023")
print("jurusan:teknik informatika")
print("fakultas teknik")
print("universitas kristen teknologi solo")
# Out:
# Latihan Algoritma dan Struktur data
# nama:Anugrah Adhiantoro
# nim:B220231008
# angkatan: 2023
# jurusan:teknik informatika
# fakultas teknik
# universitas kristen teknologi solo

# %%
print("Latihan Algoritma dan Struktur data")
print("nama:Edric Christian W")
print("nim:B220231013")
print("angkatan: 2023")
print("jurusan:teknik informatika")
print("fakultas teknik")
print("universitas kristen teknologi solo")
# Out:
# Latihan Algoritma dan Struktur data
# nama:Edric Christian W
# nim:B220231013
# angkatan: 2023
# jurusan:teknik informatika
# fakultas teknik
# universitas kristen teknologi solo

# %%
print("Latihan Algoritma dan Struktur data")
print("nama:Gosyen Abdi Imanuel")
print("nim:B220231015")
print("angkatan: 2023")
print("jurusan:teknik informatika")
print("fakultas teknik")
print("universitas kristen teknologi solo")
# Out:
# Latihan Algoritma dan Struktur data
# nama:Gosyen Abdi Imanuel
# nim:B220231015
# angkatan: 2023
# jurusan:teknik informatika
# fakultas teknik
# universitas kristen teknologi solo

# %%
print("Latihan Algoritma dan Struktur data")
print("nama:Nicholas Niki")
print("nim:B220231025")
print("angkatan: 2023")
print("jurusan:teknik informatika")
print("fakultas teknik")
print("universitas kristen teknologi solo")
# Out:
# Latihan Algoritma dan Struktur data
# nama:Nicholas Niki
# nim:B220231025
# angkatan: 2023
# jurusan:teknik informatika
# fakultas teknik
# universitas kristen teknologi solo

# %%
#Jawaban nomor 3 soal latihan
print("Ini Kita")
print("Kita berkuliah di Universitas Kristen Teknologi Surakarta") #sekolah Budi
print("Cita - cita ingin menjadi seorang Pilot") #cita-cita BUdi
# Out:
# Ini Kita
# Kita berkuliah di Universitas Kristen Teknologi Surakarta
# Cita - cita ingin menjadi seorang Pilot

# %% [markdown]
# # Modul 2

# %%
#Jawaban nomor 1 soal latihan
#tipe data Boolean
print(True)

#tipe data String
print("string dengan menggunakan tanda kutip dua")
print('ini string menggunakan tanda kutip satu')
#tipe data string dengan menjelaskan spesial karakter atau escape sequences
print('ini adalah tanda single quote (\')')
print("ini adalah tanda double quote (\")")
print("ini adalah tanda slash (\\)")
print("Algoritma\nPemrograman") #menggunakan \n
print("Algoritma\bPemrograman") #menggunakan \b
print("Algoritma\tPemrograman") #menggunakan \t
print("Algoritma\rPemrograman") #menggunakan \b

#tipe data Integer
print(20)

#tipe data Float
print(3.14)
print(.2)
print(4.2e-3)
#tipe data Binary
print(0b10)

#tipe data octal
print(0o10)

#tipe data Hexadecimal
print('tipe data heksa desimal',0x10)

#tipe data Complex
print(5j)

#tipe data List
print([1,2,3,4,5])
print(["satu", "dua", "tiga"])

#tipe data Tuple
print((1,2,3,4,5))
print(("satu", "dua", "tiga"))

#tipe data Dictionary
print({"nama":"Budi", 'umur':20})
#tipe data Dictionary dimasukan ke dalam variabel biodata
biodata = {"nama":"Budi", 'umur':21} #proses inisialisasi variabel biodata
print(biodata) #proses pencetakan variabel biodata yang berisi tipe data Dictionary
type(biodata) #fungsi untuk mengecek jenis tipe data. akan tampil <class 'dict'> yang berarti dict adalah tipe data dictionary
# Out:
# True
# string dengan menggunakan tanda kutip dua
# ini string menggunakan tanda kutip satu
# ini adalah tanda single quote (')
# ini adalah tanda double quote (")
# ini adalah tanda slash (\)
# Algoritma
# Pemrograman
# Pemrograman
# Algoritma	Pemrograman
# Pemrograman
# 20
# 3.14
# 0.2
# 0.0042
# 2
# 8
# tipe data heksa desimal 16
# 5j
# [1, 2, 3, 4, 5]
# ['satu', 'dua', 'tiga']
# (1, 2, 3, 4, 5)
# ('satu', 'dua', 'tiga')
# {'nama': 'Budi', 'umur': 20}
# {'nama': 'Budi', 'umur': 21}
# dict

# %%
#Jawaban nomor 2 soal latihan
print("Praktikum Algoritma dan Pemrograman 1 - Variable")
print("Tipe Data")
print("False")
print("<class 'bool'>")
print("Ini adalah tulisan String")
print(0b01100100)
print(1e-3)
print("bilangan desimal dari 0x01 adalah 1")
print(0o12)
print("<class 'complex'>")
print(2+6j)
print("<class 'complex'>")
print([96,97,98,99,100])
print("[seratus,dua ratus,tiga ratus]")
print({'nama': 'Ani','umur':19})
print("This string contains a single quote (') character")
# Out:
# Praktikum Algoritma dan Pemrograman 1 - Variable
# Tipe Data
# False
# <class 'bool'>
# Ini adalah tulisan String
# 100
# 0.001
# bilangan desimal dari 0x01 adalah 1
# 10
# <class 'complex'>
# (2+6j)
# <class 'complex'>
# [96, 97, 98, 99, 100]
# [seratus,dua ratus,tiga ratus]
# {'nama': 'Ani', 'umur': 19}
# This string contains a single quote (') character

# %%
#Jawaban nomor 3 soal latihan
#boolean.py
narkoba = False
belajar = True
print(narkoba)
print(belajar)
#string_format.py
first_name = "Nicholas"
middle_name = "Niki"
last_name = "Putra"

sapa = f"halo {first_name} {middle_name} {last_name}"
print(sapa)
# Out:
# False
# True
# halo Nicholas Niki Putra

# %% [markdown]
# # Modul 3

# %%
#Jawaban nomor 1 soal latihan
#memasukkan data dalam sebuah variabel
name = "Budi Bae" #isi variabel berupa string
print(name) #mencetak variabel

#nilai dan tipe data dalam variabel
age = 21 #tipe data angka / numeric
print(age) #mencetak nilai age
print(type(age)) #melihat tipe data dari age
age = "dua puluh satu" #tipe data string
print(age) #mencetak string dari age
print(type(age)) #melihat tipe data

first_name = "Monkey"
middle_name = "D."
last_name = "Luffy"
name = first_name+" "+middle_name+" "+last_name
age = 19
hobby = "Makan"
print("Profil\n",name,"\n",age,"\n",hobby)

#contoh variabel lainnya
age = 1
Age = 2
aGe = 3
AGE = 4
a_g_e = 5
_age = 6
age_ = 7
_AGE_ = 8
print(age, Age, aGe, AGE, a_g_e, _age, age_, _AGE_) #mencetak variabel

numberofcollegegraduates = 2500
NUMBEROFCOLLEGEGRADUATES = 2500
numberOfCollegeGraduates = 2500
NumberOfCollegeGraduates = 2500
number_of_college_graduates = 2500
#mencetak variabel
print(numberofcollegegraduates, NUMBEROFCOLLEGEGRADUATES,numberOfCollegeGraduates, NumberOfCollegeGraduates, number_of_college_graduates)
# Out:
# Budi Bae
# 21
# <class 'int'>
# dua puluh satu
# <class 'str'>
# Profil
#  Monkey D. Luffy
#  19
#  Makan
# 1 2 3 4 5 6 7 8
# 2500 2500 2500 2500 2500

# %%
#Jawaban nomor 2 soal latihan
#biodata
print("Nama saya Nugi yang beralamat di Karanganyar, umur sekarang 20 tahun dan memiliki hobi olahraga")
#Menghitung luas dan keliling
print("persegi panjang")
print("panjang = 15")
# Out:
# Nama saya Nugi yang beralamat di Karanganyar, umur sekarang 20 tahun dan memiliki hobi olahraga
# persegi panjang
# panjang = 15

# %%
print(0b01100100)
print(0b1010)
print(1.e2)
# Out:
# 100
# 10
# 100.0
